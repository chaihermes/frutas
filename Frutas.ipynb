# %% [markdown]
# <a href="https://colab.research.google.com/github/chaihermes/frutas/blob/main/Frutas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Subindo a base de dados
df = pd.read_excel('Frutas.xlsx')

# %%
df.head()   # Visualizando os dados
# Out:
#            Fruta  Calorias
# 0        Abacaxi        48
# 1          Amora        43
# 2        Abacate       160
# 3   Banana-prata        89
# 4  Banana-nanica        92

# %%
from sklearn.preprocessing import LabelEncoder

# Instanciando o LabelEncoder
label_encoder = LabelEncoder()

# Atribuindo valores numéricos e armazenando em outra coluna
df['CategoriasFrutas'] = label_encoder.fit_transform(df['Fruta'])

# %%
df.head()   # Visualizando o resultado com o LabelEncoder
# Out:
#            Fruta  Calorias  CategoriasFrutas
# 0        Abacaxi        48                 1
# 1          Amora        43                 4
# 2        Abacate       160                 0
# 3   Banana-prata        89                 7
# 4  Banana-nanica        92                 6

# %% [markdown]
# **One Hot Enconding / Dummies**

# %%
#Subindo a base dos dados:
df = pd.read_excel('Frutas.xlsx')

# Criando a classificação binária por tipo de categoria
dum_df = pd.get_dummies(df, columns=["Fruta"])

# %%
dum_df
# Out:
#     Calorias  Fruta_Abacate  Fruta_Abacaxi  Fruta_Acerola  Fruta_Ameixa  \
# 0         48          False           True          False         False
# 1         43          False          False          False         False
# 2        160           True          False          False         False
# 3         89          False          False          False         False
# 4         92          False          False          False         False
# 5         89          False          False          False         False
# 6         46          False          False          False         False
# 7         70          False          False          False         False
# 8         31          False          False          False         False
# 9         43          False          False          False         False
# 10        46          False          False          False          True
# 11        32          False          False           True         False
# ...
